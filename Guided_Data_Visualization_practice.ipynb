# %%
import pandas as pd 
import numpy as np
#seaborn for data visualization
import seaborn as sns
import matplotlib.pyplot as plt

# %%
test=pd.read_csv('test.csv')

# %%
test
# Out:
#              ID  Loan Amount  Funded Amount  Funded Amount Investor  Term  \
# 0      56492997        17120          10365            16025.082690    59
# 1      22540813         7133          11650            12615.795600    59
# 2       9862181        25291          25825            11621.280830    59
# 3      10097822        30781           9664            15375.823510    59
# 4      47771809         8878           9419             7176.647582    58
# ...         ...          ...            ...                     ...   ...
# 28908  11537800        35000          35000            35000.000000    60
# 28909  11538258        25000          25000            25000.000000    60
# 28910  13147685        30000          30000            29950.000000    60
# 28911  13917689        25000          25000            24950.000000    60
# 28912  10763026        24925          24925            24925.000000    60
#
#       Batch Enrolled  Interest Rate Grade Sub Grade Employment Duration  ...  \
# ...

# %%
train=pd.read_csv('train.csv')

# %%
train
# Out:
#              ID  Loan Amount  Funded Amount  Funded Amount Investor  Term  \
# 0      65087372        10000          32236             12329.36286    59
# 1       1450153         3609          11940             12191.99692    59
# 2       1969101        28276           9311             21603.22455    59
# 3       6651430        11170           6954             17877.15585    59
# 4      14354669        16890          13226             13539.92667    59
# ...         ...          ...            ...                     ...   ...
# 67458  16164945        13601           6848             13175.28583    59
# 67459  35182714         8323          11046             15637.46301    59
# 67460  16435904        15897          32921             12329.45775    59
# 67461   5300325        16567           4975             21353.68465    59
# 67462  65443173        15353          29875             14207.44860    59
#
#       Batch Enrolled  Interest Rate Grade Sub Grade Employment Duration  ...  \
# ...

# %%
test.columns
# Out:
# Index(['ID', 'Loan Amount', 'Funded Amount', 'Funded Amount Investor', 'Term',
#        'Batch Enrolled', 'Interest Rate', 'Grade', 'Sub Grade',
#        'Employment Duration', 'Home Ownership', 'Verification Status',
#        'Payment Plan', 'Loan Title', 'Debit to Income',
#        'Delinquency - two years', 'Inquires - six months', 'Open Account',
#        'Public Record', 'Revolving Balance', 'Revolving Utilities',
#        'Total Accounts', 'Initial List Status', 'Total Received Interest',
#        'Total Received Late Fee', 'Recoveries', 'Collection Recovery Fee',
#        'Collection 12 months Medical', 'Application Type', 'Last week Pay',
#        'Accounts Delinquent', 'Total Collection Amount',
#        'Total Current Balance', 'Total Revolving Credit Limit', 'Loan Status'],
#       dtype='object')

# %%
train.columns
# Out:
# Index(['ID', 'Loan Amount', 'Funded Amount', 'Funded Amount Investor', 'Term',
#        'Batch Enrolled', 'Interest Rate', 'Grade', 'Sub Grade',
#        'Employment Duration', 'Home Ownership', 'Verification Status',
#        'Payment Plan', 'Loan Title', 'Debit to Income',
#        'Delinquency - two years', 'Inquires - six months', 'Open Account',
#        'Public Record', 'Revolving Balance', 'Revolving Utilities',
#        'Total Accounts', 'Initial List Status', 'Total Received Interest',
#        'Total Received Late Fee', 'Recoveries', 'Collection Recovery Fee',
#        'Collection 12 months Medical', 'Application Type', 'Last week Pay',
#        'Accounts Delinquent', 'Total Collection Amount',
#        'Total Current Balance', 'Total Revolving Credit Limit', 'Loan Status'],
#       dtype='object')

# %%
#new_df=test.append(train, ignore_index=True)


frames = [test, train]
new_df = pd.concat(frames)

# %%
new_df
# Out:
#              ID  Loan Amount  Funded Amount  Funded Amount Investor  Term  \
# 0      56492997        17120          10365            16025.082690    59
# 1      22540813         7133          11650            12615.795600    59
# 2       9862181        25291          25825            11621.280830    59
# 3      10097822        30781           9664            15375.823510    59
# 4      47771809         8878           9419             7176.647582    58
# ...         ...          ...            ...                     ...   ...
# 67458  16164945        13601           6848            13175.285830    59
# 67459  35182714         8323          11046            15637.463010    59
# 67460  16435904        15897          32921            12329.457750    59
# 67461   5300325        16567           4975            21353.684650    59
# 67462  65443173        15353          29875            14207.448600    59
#
#       Batch Enrolled  Interest Rate Grade Sub Grade Employment Duration  ...  \
# ...

# %%
new_df.describe()
# Out:
#                  ID   Loan Amount  Funded Amount  Funded Amount Investor  \
# count  9.637600e+04  96376.000000   96376.000000            96376.000000
# mean   2.677423e+07  16715.439259   15725.392401            14657.720784
# std    2.146078e+07   8367.617027    8175.017327             6922.046851
# min    1.297893e+06   1000.000000    1000.000000             1000.000000
# 25%    7.003730e+06   9953.000000    9238.000000             9800.036208
# 50%    1.996712e+07  15947.000000   13076.000000            12826.006220
# 75%    4.439923e+07  21987.250000   21724.000000            18382.681483
# max    7.226845e+07  35000.000000   35000.000000            35000.000000
#
#                Term  Interest Rate  Home Ownership  Debit to Income  \
# count  96376.000000   96376.000000    96376.000000     96376.000000
# mean      57.084585      11.948654    80374.176313        22.957246
# std        5.896938       3.780666    45090.364452         8.530055
# ...

# %%
new_df['Employment Duration'].unique()
# Out:
# array(['RENT', 'MORTGAGE', 'OWN'], dtype=object)

# %%
new_df['Grade'].unique()
# Out:
# array(['A', 'B', 'C', 'E', 'D', 'F', 'G'], dtype=object)

# %%
new_df['Sub Grade'].unique()
# Out:
# array(['D1', 'E3', 'C3', 'A2', 'B3', 'B2', 'C2', 'B4', 'D3', 'B5', 'C1',
#        'A3', 'A5', 'F5', 'F4', 'E4', 'A4', 'E5', 'C5', 'A1', 'D2', 'E2',
#        'F1', 'D5', 'C4', 'F3', 'B1', 'D4', 'E1', 'G4', 'G1', 'G2', 'F2',
#        'G3', 'G5'], dtype=object)

# %%
new_df
# Out:
#              ID  Loan Amount  Funded Amount  Funded Amount Investor  Term  \
# 0      56492997        17120          10365            16025.082690    59
# 1      22540813         7133          11650            12615.795600    59
# 2       9862181        25291          25825            11621.280830    59
# 3      10097822        30781           9664            15375.823510    59
# 4      47771809         8878           9419             7176.647582    58
# ...         ...          ...            ...                     ...   ...
# 67458  16164945        13601           6848            13175.285830    59
# 67459  35182714         8323          11046            15637.463010    59
# 67460  16435904        15897          32921            12329.457750    59
# 67461   5300325        16567           4975            21353.684650    59
# 67462  65443173        15353          29875            14207.448600    59
#
#       Batch Enrolled  Interest Rate Grade Sub Grade Employment Duration  ...  \
# ...

# %%
new_df.columns
# Out:
# Index(['ID', 'Loan Amount', 'Funded Amount', 'Funded Amount Investor', 'Term',
#        'Batch Enrolled', 'Interest Rate', 'Grade', 'Sub Grade',
#        'Employment Duration', 'Home Ownership', 'Verification Status',
#        'Payment Plan', 'Loan Title', 'Debit to Income',
#        'Delinquency - two years', 'Inquires - six months', 'Open Account',
#        'Public Record', 'Revolving Balance', 'Revolving Utilities',
#        'Total Accounts', 'Initial List Status', 'Total Received Interest',
#        'Total Received Late Fee', 'Recoveries', 'Collection Recovery Fee',
#        'Collection 12 months Medical', 'Application Type', 'Last week Pay',
#        'Accounts Delinquent', 'Total Collection Amount',
#        'Total Current Balance', 'Total Revolving Credit Limit', 'Loan Status'],
#       dtype='object')

# %%
## how to see all columns on jupyter notebook

# %%
pd.set_option('display.max_columns', None)

# %%
new_df
# Out:
#              ID  Loan Amount  Funded Amount  Funded Amount Investor  Term  \
# 0      56492997        17120          10365            16025.082690    59
# 1      22540813         7133          11650            12615.795600    59
# 2       9862181        25291          25825            11621.280830    59
# 3      10097822        30781           9664            15375.823510    59
# 4      47771809         8878           9419             7176.647582    58
# ...         ...          ...            ...                     ...   ...
# 67458  16164945        13601           6848            13175.285830    59
# 67459  35182714         8323          11046            15637.463010    59
# 67460  16435904        15897          32921            12329.457750    59
# 67461   5300325        16567           4975            21353.684650    59
# 67462  65443173        15353          29875            14207.448600    59
#
#       Batch Enrolled  Interest Rate Grade Sub Grade Employment Duration  \
# ...

# %%
## Correlation analysis

# %%
new_df.corr()
# Out:
#                                     ID  Loan Amount  Funded Amount  \
# ID                            1.000000    -0.011808      -0.006791
# Loan Amount                  -0.011808     1.000000       0.080939
# Funded Amount                -0.006791     0.080939       1.000000
# Funded Amount Investor        0.006261     0.093500       0.104556
# Term                         -0.112054     0.101967       0.077600
# Interest Rate                 0.008160    -0.001493       0.013031
# Home Ownership               -0.009531     0.049870       0.033022
# Debit to Income              -0.028820     0.014854       0.007287
# Delinquency - two years       0.000109    -0.004705       0.009175
# Inquires - six months         0.025454    -0.013167      -0.012029
# Open Account                 -0.017210     0.026257       0.018220
# Public Record                 0.028362    -0.015701      -0.010725
# Revolving Balance             0.056631     0.038556       0.048304
# ...

# %%
import seaborn as sns
#import matplotlib as plt

#plt.figure(figsize=(40,20))
#sns.heatmap(new_df.corr(), annot=True)
#plt.show()

plt.figure(figsize=(40,20))
sns.heatmap(new_df.corr(), annot=True)
plt.show()

# %%
sns.countplot(x="Loan Status", data=train)
plt.show()

# %% [markdown]
# # Class Imbalance
#
# ###  Read about handling class imbalance in machine learning
#
#
# # different strategies often include resampling

# %%
sns.countplot(x="Loan Status", hue="Grade", data=new_df)
plt.show()

# %%
## Percentage of default for grade A, B, C.....

# %%
grade_a=train[train['Grade']=='A']

# %%
grade_a
# Out:
#              ID  Loan Amount  Funded Amount  Funded Amount Investor  Term  \
# 7      63151650        20744          10609             7645.014802    58
# 11      3975562        16581           8767            10637.049030    59
# 16     48621970        25721          25880            12038.601890    58
# 19      9038338        14058          26523             9622.342364    59
# 25      6688651        15330          21812            12374.390930    59
# ...         ...          ...            ...                     ...   ...
# 67437   9424725        33062           8615             9046.096550    59
# 67438  64968645         3443          31515            30719.692480    58
# 67442   9052816        26689          12688             9604.161633    59
# 67453  14669554        31161          16000             8386.746929    59
# 67460  16435904        15897          32921            12329.457750    59
#
#       Batch Enrolled  Interest Rate Grade Sub Grade Employment Duration  \
# ...

# %%
grade_a_non_DF = len(train[(train["Grade"]=="A") & 
         (train["Loan Status"]==0)])
print(grade_a_non_DF)
# Out:
# 10955

# %%
grade_a_DF = len(train[(train["Grade"]=="A") & 
         (train["Loan Status"]==1)])
print(grade_a_DF)
# Out:
# 1100

# %%
train['Loan Title'].unique()
# Out:
# array(['Debt Consolidation', 'Debt consolidation',
#        'Credit card refinancing', 'Home improvement',
#        'Credit Consolidation', 'Green loan', 'Other',
#        'Moving and relocation', 'Credit Cards', 'Medical expenses',
#        'DEBT CONSOLIDATION', 'Home Improvement', 'Refinance',
#        'credit card consolidation', 'Lending Club',
#        'Debt Consolidation Loan', 'Major purchase', 'Vacation',
#        'Business', 'Credit card payoff', 'Credit Card Consolidation',
#        'credit card', 'Credit Card Refi', 'Personal Loan', 'CC Refi',
#        'consolidate', 'Medical', 'Loan 1', 'Consolidation',
#        'Card Consolidation', 'Car financing', 'debt', 'home improvement',
#        'debt consolidation', 'Home buying', 'Freedom', 'Consolidate',
#        'Consolidated', 'get out of debt', 'consolidation loan',
#        'Dept consolidation', 'Personal loan', 'Personal', 'Debt', 'cards',
#        'Cards', 'Bathroom', 'refi', 'Credit Card Loan',
# ...

# %%
sns.countplot(x="Loan Status", hue="Verification Status", data=new_df)
plt.show()

# %%
#Employment Duration

sns.countplot(x="Loan Status", hue="Employment Duration", data=new_df)
plt.show()
