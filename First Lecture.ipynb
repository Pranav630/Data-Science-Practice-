# %% [markdown]
# # Itinerary
#
# ### Python
# ### Packages
# ### resources
# ### Download Anaconda
# ### The learning curve
# ### Jupyter Notebook
# ### Working with data
# ### handoffs and restarting notebook

# %%
## ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %% [markdown]
# ## Why python?
#
# ### Free software with very accessible resources.
# ### Diverse capabilities

# %%
## ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %% [markdown]
# # Helpful packages
#
# ### numpy
# ### pandas
# ### matplotlib

# %%
## ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %%
import pandas as pd

# %% [markdown]
# # Helpful resources
#
# ### Stack Overflow
# ### Youtube

# %%
## ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %% [markdown]
# # Download Processs
#
# Anaconda

# %%
## ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~



OPEN up jupyter notebook 

review file options 

Documents folder

# %% [markdown]
# # The learning curve
# -Understanding how to search for the answer to your question
# -Think of other ways to ask your question

# %%
## ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %% [markdown]
# # Important keys in Jupyter notebook

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
## ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %% [markdown]
# # Working with data
#
# How to bring data into the python notepook
# -Have the same file path

# %%
## ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~


CSV files 
Excel files
TXT files

# %%
#c=pd.read_excel('Example Table.xlsx')

for i in range(900000):
    print(i/3)
# Out:
# 0.0
# 0.3333333333333333
# 0.6666666666666666
# 1.0
# 1.3333333333333333
# 1.6666666666666667
# 2.0
# 2.3333333333333335
# 2.6666666666666665
# 3.0
# 3.3333333333333335
# 3.6666666666666665
# 4.0
# 4.333333333333333
# 4.666666666666667
# 5.0
# 5.333333333333333
# 5.666666666666667
# 6.0
# 6.333333333333333
# 6.666666666666667
# 7.0
# 7.333333333333333
# 7.666666666666667
# 8.0
# 8.333333333333334
# 8.666666666666666
# 9.0
# 9.333333333333334
# 9.666666666666666
# 10.0
# 10.333333333333334
# 10.666666666666666
# 11.0
# 11.333333333333334
# 11.666666666666666
# 12.0
# 12.333333333333334
# 12.666666666666666
# 13.0
# 13.333333333333334
# 13.666666666666666
# 14.0
# 14.333333333333334
# 14.666666666666666
# 15.0
# 15.333333333333334
# 15.666666666666666
# 16.0
# 16.333333333333332
# 16.666666666666668
# 17.0
# 17.333333333333332
# 17.666666666666668
# 18.0
# 18.333333333333332
# 18.666666666666668
# 19.0
# 19.333333333333332
# 19.666666666666668
# 20.0
# 20.333333333333332
# ...

# %%
example_table
# Out:
#                  Description  Task  Tier  time (hours)
# 0                      Sleep     1     1           6.0
# 1      Shower, bathroom time     2     1           1.0
# 2   Breakfast, lunch, dinner     3     1           3.0
# 3                       work     4     1           6.5
# 4                 networking     5     2           1.0
# 5                        run     6     2           0.5
# 6                 oil change     7     2           1.0
# 7                wash dishes     8     2           7.0
# 8                   mow lawn     9     3           0.6
# 9                resume work    10     3           1.0
# 10             toilet repair    11     3           7.5
# 11                   laundry    12     3           2.0
# 12                       NaN    13     3           0.2
# 13                       NaN    14     3           0.3
# 14                       NaN    15     3           0.1

# %% [markdown]
# # kaggle.com
#
#
# Free massive datasets for data analystics and data science practice

# %% [markdown]
# # Hand offs and re-starting the module

# %%
x= 'apple'

# %%
#x='orange'

# %%
print(x)
# Out:
# apple
